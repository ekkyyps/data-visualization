# %% [markdown]
# ## Tugas Besar 1
# ### MK Visualisasi Data Gasal 2020/2021

# %% [markdown]
# <b>Nama<b>: Ekky Yulianti Prastika S.<br>
# <b>NIM<b>: 1301174038

# %% [markdown]
# #### Aturan umum:
# 1. Setiap soal dievaluasi berdasarkan _code program_ dan penjelasan yang dibuat.
# 2. File _midterm project_ yang telah dikerjakan harus di-submit melalui LMS.
# 3. Batas akhir submit file adalah 1 November 2020 pukul 21:00.
# 4. <b><font color='red'>Setiap tindakan plagiarism akan berakibat pada ketidaklulusan pada MK ini.</font><b>

# %% [markdown]
# ### Kasus 1: Pima Indian Diabetes Data Set (Soal 1 - 2)
# Dataset ini berasal dari the National Institute of Diabetes and Digestive and Kidney Diseases. Tujuan dari pengumpulan dataset ini untuk dapat memprediksi secara diagnosis apakah seseorang mengidap penyakit diabetes atau tidak berdasarkan beberapa pengukuran diagnostik. Seluruh pasien pada dataset ini adalah perempuan keturunan India Pima yang berumur kurang dari 21 tahun.<br><br>
# Dataset terdiri dari beberapa variabel prediktor medis dan satu variabel target sebagai _outcome_. Variabel prediktor di antaranya jumlah kehamilan, BMI, level insulin, usia, dll.lin level, age, and so on. Dataset dapat diunduh melalui [tautan ini](https://www.dl.dropboxusercontent.com/s/3i3gfr8pih4jwd4/diabetes.csv?dl=0)

# %% [markdown]
# ### Soal 1 (15 poin)
# Tampilkan visualisasi distribusi data untuk variabel "Glucose" dan "Insulin", lalu jelaskan hasil distribusinya.

# %% [markdown]
# #### Code

# %%
# timport library
import numpy as np
import pandas as pd

# %%
# load the dataset
dataset = pd.read_csv('diabetes.csv')
dataset
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
# Took 2 Columns using loc
df_histogram = dataset.loc[:, ('Glucose', 'Insulin')]
df_histogram.head(2)
# Out:
#    Glucose  Insulin
# 0      148        0
# 1       85        0

# %%
# Check if the dataset has any null values  
df_histogram.isnull().sum()
# Out:
# Glucose    0
# Insulin    0
# dtype: int64

# %%
# import library for visualization
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# __Visualization using Histogram__

# %%
# using histogram for checking the distribution

df_histogram.plot(kind ='hist',
            figsize=(15, 5),
            bins=30,
            alpha=0.5,
            color=['blue', 'mediumseagreen'])

plt.title('Histogram of Glucose and Insulin') # add a title to the histogram
plt.xlabel('Number of Insulin and Glucose') # add x-label
plt.ylabel('Number of People or Frequency') # add y-label

plt.show()

#satistics
# df_histogram.describe()

# %% [markdown]
# #### Penjelasan
#
# Visualisasi di atas termasuk **Left Skewed Histogram** adalah histogram yang memiliki tail yang panjang di sebelah kiri yang berarti distribusinya tidak normal.
#
# Berdasarkan hasil distribusi di atas didapatkan bahwa persebaran data untuk insulin ditemukan sebanyak +- 350 lebih orang yang memiliki insulin 0. Sedangkan, untuk kadar Glukosa tertinggi ditemukan pada rentang jumlah 0 s/d +- 200 dengan frekuensi rentang 0 s/d +- 275.

# %% [markdown]
# ### Soal 2 (25 poin)
# Tampilkan visualisasi dari korelasi (i) antar variabel dan (ii) antara variabel dan target, lalu jelaskan hasil korelasinya.

# %% [markdown]
# #### Code

# %%
# Drop table
df_cor = dataset.drop(columns='Outcome')
# Correlation between Variables without Outcome because it use to be Target
cor = df_cor.corr(method='pearson')

# %%
plt.figure(figsize=(9,7))
sns.heatmap(cor, 
            xticklabels=cor.columns,
            yticklabels=cor.columns,
            cmap='RdBu_r',
            annot=True,
            linewidth=0.5)
plt.title('(i) Correlation Between Variables')
plt.show()

# %%
# Correlation between Variable and Target
df_cor2 = dataset.copy()

figure = plt.subplots(figsize = (8,7))
plt.title('(ii) Correlation between Variables and Target')
sns.heatmap(df_cor2.corr()[['Outcome']], annot = True, fmt='.1g',vmin=-1, vmax=1, center= 0)

# %% [markdown]
# #### Penjelasan
#
# **(i)** Dengan menggunakan metode Pearson Correlation bahwa korelasi yang mendekati dengan angka 1 disebut berkorelasi positif yang mana ia sangat berkorelasi, berdasarkan visualisasi di atas yaitu antara variabel **Glucose** dengan variabel **Glucose**. Hal ini dikarenakan kedua variabel tersebut similar.
# Pearson Correlation Method juga mengatakan bahwa variabel-varibel yang memiliki nilai korelasi positif adalah memiliki nilai korelasi sebesar > 0,5.
#
# _"Semakin tebal warnanya, semakin berkorelasi antar variabelnya"_
#
# Berdasarkan visualisasi di atas didapatkan juga korelasi antara variabel **Age** dengan **Pregnancies** sebesar **0,54** menurut Pearson Correlation variabel-variabel tsb masih memiliki nilai korelasi positif. Hal tersebut berarti variabel **Age** dan varibel **Pregnancies** memiliki keterkaitan satu sama lain.
#
# Visualisasi di atas merupakan hasil korelasi antar variabel-variabel tanpa variabel **Outcome** karena variabel tersebut digunakan sebagai Target.
#
# **(ii)** Berdasarkan hasil visualisasi di atas didapatkan korelasi positif pada Variabel **Glucose** dengan Target **Outcome** yaitu sebesar 0,5. Korelasi antar Variabel dengan Target berada rentang 0-0,5 dengan korelasi paling tinggi dimiliki oleh Variabel **Glucose**.

# %% [markdown]
# ### Kasus 2: Stock Market Analysis (Soal 3 - 4)
# Pada kasus ini, kita akan membandingkan beberapa parameter yang diturunkan dari data historis harga saham dari 3 perusahaan, yaitu Nasdaq, Nikkei dan Hang Seng. Data set dapat diunduh melalui [tautan ini](https://www.dl.dropboxusercontent.com/s/0wny6x5sio9nvap/stock_market.zip?dl=0).

# %% [markdown]
# ### Soal 3 (30 poin)
# Lakukanlah _trend analysis_ nilai _daily percentage change_ dari ketiga harga saham tersebut selama tahun 2019, lalu tampilkan dan jelaskan melalui visualisasi data.
# _Trend analysis_ dilakukan dengan menggunakan hubungan berikut:
# ![output%2011.png](https://www.dl.dropboxusercontent.com/s/dxmrm74ksz5l9v2/trend_analysis_fig.png?dl=0)

# %% [markdown]
# #### Code

# %%
# Load the dataset
dataset_hang = pd.read_csv("Hang_Seng.csv")
dataset_nasd = pd.read_csv("Nasdaq.csv")
dataset_nikk = pd.read_csv("Nikkei.csv")

# %% [markdown]
# Preprocessing

# %%
# Checking null dataset Han_Seng
dataset_hang.isnull().sum()
# Handling with drop the null
dataset_hang.dropna(inplace = True, axis = 0)

# %%
# Checking null dataset Nasdaq
dataset_nasd.isnull().sum()
# Handling with drop the null
dataset_nasd.dropna(inplace = True, axis = 0)

# %%
# Checking null dataset Nikkei
dataset_nikk.isnull().sum()
# Handling with drop the null
dataset_nikk.dropna(inplace = True, axis = 0)

# %%
df_hang = dataset_hang.round(2)
df_nssd = dataset_nasd.round(2)
df_nikk = dataset_nikk.round(2)

# %%
df_hang.head(3)
# Out:
#          Date      Open      High       Low     Close  Adj Close        Volume
# 0  2018-10-19  25172.03  25743.45  25090.30  25561.40   25561.40  2.037872e+09
# 1  2018-10-22  25668.33  26234.86  25668.33  26153.15   26153.15  2.222812e+09
# 2  2018-10-23  26015.49  26015.49  25315.76  25346.55   25346.55  1.772912e+09

# %% [markdown]
# Calculate Daily Percentage

# %%
df_hang["Day_Perc_Change"] = df_hang["Adj Close"].pct_change()*100
df_hang.head(3)
# Out:
#          Date      Open      High       Low     Close  Adj Close  \
# 0  2018-10-19  25172.03  25743.45  25090.30  25561.40   25561.40
# 1  2018-10-22  25668.33  26234.86  25668.33  26153.15   26153.15
# 2  2018-10-23  26015.49  26015.49  25315.76  25346.55   25346.55
#
#          Volume  Day_Perc_Change
# 0  2.037872e+09              NaN
# 1  2.222812e+09         2.315014
# 2  1.772912e+09        -3.084141

# %%
df_nssd["Day_Perc_Change"] = df_nssd["Adj Close"].pct_change()*100
df_nssd.head(3)
# Out:
#          Date     Open     High      Low    Close  Adj Close      Volume  \
# 0  2018-10-19  7530.16  7582.89  7428.30  7449.03    7449.03  2532220000
# 1  2018-10-22  7486.74  7520.54  7424.74  7468.63    7468.63  2282400000
# 2  2018-10-23  7328.55  7472.58  7260.13  7437.54    7437.54  2735820000
#
#    Day_Perc_Change
# 0              NaN
# 1         0.263122
# 2        -0.416274

# %%
df_nikk["Day_Perc_Change"] = df_nikk["Adj Close"].pct_change()*100
df_nikk.head(3)
# Out:
#          Date      Open      High       Low     Close  Adj Close   Volume  \
# 0  2018-10-19  22342.00  22551.67  22212.57  22532.08   22532.08  67400.0
# 1  2018-10-22  22374.21  22672.25  22271.59  22614.82   22614.82  63000.0
# 2  2018-10-23  22404.14  22410.15  21993.07  22010.78   22010.78  80200.0
#
#    Day_Perc_Change
# 0              NaN
# 1         0.367210
# 2        -2.670992

# %%
df_hang.iloc[-90:].describe().astype(int)
# Out:
#         Open   High    Low  Close  Adj Close      Volume  Day_Perc_Change
# count     90     90     90     90         90          90               90
# mean   24819  24973  24586  24762      24762  1847891047                0
# std      652    662    621    642        642   635710242                1
# min    23284  23495  23124  23235      23235           0               -2
# 25%    24382  24572  24200  24434      24434  1459246075                0
# 50%    24816  24957  24581  24729      24729  1750760150                0
# 75%    25232  25359  25034  25178      25178  2097051475                0
# max    26571  26782  26016  26339      26339 -2147483648                3

# %% [markdown]
# Trend Analysis

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
def trend(x):
    if x > -0.5 and x <= 0.5:
        return "Slight or No change"
    elif x > 0.5 and x <= 1:
        return "Slight Positive"
    elif x > -1 and x <= -0.5:
        return "Slight Negative"
    elif x > 1 and x <= 3:
        return "Positive"
    elif x > -3 and x <= -1:
        return "Negative"
    elif x > 3 and x <= 7:
        return "Among top gainers"
    elif x > -7 and x <= -3:
        return "Among top losers"
    elif x > 7:
        return "Bull run"
    elif x <= -7:
        return "Bear drop"

# %%
df_hang["Trend"]= df_hang["Day_Perc_Change"].apply(lambda x:trend(x))
# df_hang.head()
df_nssd["Trend"]= df_nssd["Day_Perc_Change"].apply(lambda x:trend(x))
# df_nssd.head()
df_nikk["Trend"]= df_nikk["Day_Perc_Change"].apply(lambda x:trend(x))
# df_nikk.head()

# %% [markdown]
# Set Date

# %%
from datetime import datetime

# %%
start = '2019-01-01'
end = '2019-12-31'
df_hang = df_hang.loc[(df_hang['Date'] >= start) & (df_hang['Date'] <= end)]
df_nssd = df_nssd.loc[(df_nssd['Date'] >= start) & (df_nssd['Date'] <= end)]
df_nikk = df_nikk.loc[(df_nikk['Date'] >= start) & (df_nikk['Date'] <= end)]

# %% [markdown]
# Pie Chart Han_Seng

# %%
pie_data = df_hang.groupby(['Trend'])
pie_label = sorted([i for i in df_hang.loc[:, 'Trend'].unique()])
plt.pie(pie_data['Trend'].count(), labels = pie_label, 
        autopct = '%1.1f%%', radius = 1)
plt.title("Trend Analysis of Han_Seng", bbox={'facecolor':'0.8', 'pad':5})

plt.show()

# %% [markdown]
# Pie Chart Nasdaq

# %%
pie_data_nssd = df_nssd.groupby(['Trend'])
pie_label_nssd = sorted([i for i in df_nssd.loc[:, 'Trend'].unique()])
plt.pie(pie_data_nssd['Trend'].count(), labels = pie_label_nssd, 
        autopct = '%1.1f%%', radius = 1)
plt.title("Trend Analysis of Nasdaq", bbox={'facecolor':'0.8', 'pad':5})

plt.show()

# %%
pie_data_nikk = df_nikk.groupby(['Trend'])
pie_label_nikk = sorted([i for i in df_nikk.loc[:, 'Trend'].unique()])
plt.pie(pie_data_nikk['Trend'].count(), labels = pie_label_nikk, 
        autopct = '%1.1f%%', radius = 1)
plt.title("Trend Analysis of Nikkei", bbox={'facecolor':'0.8', 'pad':5})

plt.show()

# %% [markdown]
# #### Penjelasan
#
# Berdasarkan hasil visualisasi dari tren "Slight or No Change" untuk saham Han_Seng selama transaksi dari periode Januari 2019 hingga Desember 2019 didapatkan sebanyak 48,4%. Sedangkan untuk saham Nasdaq sebanyak 46% dan saham Nikkei sebesar 52,7%. Hal ini berarti dari ketiga data tersebut mengalami perubahan harga saham yang setiap harinya(hari ini dengan kemarin) tidak jauh berbeda sehingga potensi dari ketiganya memiliki keuntungan yang kecil.
#
# _"**Persentase** tren **Slight ot No Change** berbanding terbalik dengan **Potensi Keuntungan** yang didapatkan"_
#
# Dapat disimpulkan bahwa Nikkei memiliki keuntungan yang terkecil karena persentase untuk tren "Slight or No Change" memiliki persentase paling besar diantara saham Han_Seng dan saham Nasdaq.

# %% [markdown]
# ### Soal 4 (30 poin)
# Lakukanlah analisis volatilitas dari ketiga harga saham tersebut selama tahun 2019, lalu tampilkan dan jelaskan hasil visualisasinya.

# %% [markdown]
# #### Code

# %%
df_combination= pd.concat([df_hang["Adj Close"], df_nssd["Adj Close"], df_nikk["Adj Close"]], axis=1)
df_combination.columns = ["Hang_Seng", "Nasdaq", "Nikkei"]

df_combination.dropna(inplace = True, axis = 0)
df_percent_combined = df_combination.pct_change()*100
df_percent_combined.dropna(inplace = True, how = "any", axis = 0)

df_percent_combined
# Out:
#      Hang_Seng    Nasdaq    Nikkei
# 53    0.818192  1.077604  2.438457
# 54    0.153857  0.871103  0.823745
# 55    2.268057  0.416698  1.103839
# 56    0.223374 -0.208844 -1.288781
# 57    0.549895 -0.940403  0.971543
# ..         ...       ...       ...
# 288   0.145455  0.731103  0.039755
# 289  -0.300242  0.201438 -0.200205
# 290   0.254888  0.908427  0.597279
# 291   0.125792  0.103583 -0.364474
# 292  -0.151220  0.049641 -0.759720
#
# [240 rows x 3 columns]

# %%
volatility = df_percent_combined.rolling(7).std()*np.sqrt(7)
volatility.plot(figsize = (15,7))

plt.title('Volatility of Han_Seng, Nasdaq, and Nikkei')
plt.show()

# %% [markdown]
# #### Penjelasan
#
# Dapat dilihat bahwa Han_Seng cenderung volatilitasnya stabil daripada Nasdaq. Nasdaq cenderung memiliki volatilitas yang tinggi daripada Han_Seng dan Nikkei. Hal ini akan menarik banyak pedagang dan investor karena mereka mencari investasi volatilitas yang lebih tinggi untuk mendapatkan keuntungan yang lebih tinggi. Jika suatu saham tidak bergerak, tidak hanya memiliki volatilitas yang rendah, tetapi juga potensi keuntungan yang rendah. Di sisi lain, saham atau sekuritas lain dengan tingkat volatilitas yang sangat tinggi dapat memiliki potensi keuntungan yang luar biasa, tetapi risikonya juga sama tingginya. Sedangkan, jika pemula lebih baik mencari yang stabil seperti milik Han_Seng karena risiko juga tidak terlalu tinggi.
